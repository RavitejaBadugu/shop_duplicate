# %%
# !python ../input/gitfiles/shop_duplicate-experiment/EDA.py --data_path ../input/gitfiles/shop_duplicate-experiment/train.csv --images_base_path ../input/gitfiles/shop_duplicate-experiment/train_images

# %%
# !python ../input/gitfiles/shop_duplicate-experiment/create_fold.py --data_path "processed_data/cleaned_data.csv"
# Out:
# label encoding is done
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:680: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   UserWarning,
# created the kfold
# stratified kfold data is stored at processed_data/fold_data.csv

# %%
# !mkdir models_dir

# %%
# !python ../input/gitfiles/shop_duplicate-experiment/training.py --data_path processed_data/fold_data.csv --model_type "text" --batch_size 32 --save_model_path "models_dir/bert" --FOLDS 3 --epochs 30 --lr_callback "None"
# Out:
# Downloading: 100%|██████████████████████████████| 570/570 [00:00<00:00, 412kB/s]
# Downloading: 100%|███████████████████████████| 511M/511M [00:45<00:00, 11.9MB/s]
# 2022-06-09 07:09:49.514975: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-09 07:09:49.516395: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-09 07:09:49.517355: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
from IPython.display import FileLink
#FileLink("models_dir/bert2.h5")
